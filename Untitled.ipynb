# %%
rf = RandomForestClassifier(
    n_estimators=300,
    random_state=42,
    class_weight="balanced"
)

pipe = Pipeline([
    ("prep", preprocessor),
    ("rf", rf)
])

pipe.fit(X_train, y_train)

bundle = {
    "pipeline": pipe,
    "diagnosis_options": sorted(df_raw[COL_DIAG].dropna().unique()),
    "kelas_target": sorted(y_train.unique())
}

import joblib
joblib.dump(bundle, "model_diet_proyek.pkl")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 rf = RandomForestClassifier(
#       2     n_estimators=300,
#       3     random_state=42,
#       4     class_weight="balanced"
#       5 )
#       7 pipe = Pipeline([
#       8     ("prep", preprocessor),
#       9     ("rf", rf)
#      10 ])
#      12 pipe.fit(X_train, y_train)
#
# NameError: name 'RandomForestClassifier' is not defined
